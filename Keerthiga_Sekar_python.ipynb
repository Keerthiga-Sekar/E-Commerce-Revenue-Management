# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv("E-Commerce.csv")

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# #### Ans 1 a)

# %%
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# The head() and tail() methods are used here to fetch the first 10 rows and last 10 rows from the dataframe.

# %% [markdown]
# # Ans 1 b)

# %%
ECom_Data.shape
# Out:
# (8906, 17)

# %% [markdown]
# There are 8906 rows and 17 columns in the dataset.

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %%
x=len(ECom_Data)
y=len(ECom_Data.columns)
x,y
# Out:
# (8906, 17)

# %% [markdown]
# .shape attribute is used to get the number of rows and columns in the dataset.len() and info() are the other two different methods I have used here to extract the same information.

# %% [markdown]
# #### Ans  1 c)

# %%
object_column=ECom_Data.select_dtypes(include=['object'])
Total_object_column=len(object_column.columns)
print('Total number of object datatype in the dataset is',Total_object_column)
# Out:
# Total number of object datatype in the dataset is 14

# %% [markdown]
# There are 14 object datatypes in the dataset.

# %% [markdown]
# ### Ans 1 d)

# %%
bool_column=ECom_Data.select_dtypes(include=['boolean'])
Total_bool_column=len(bool_column.columns)
print('Total number of boolean datatype in the dataset is',Total_bool_column)
# Out:
# Total number of boolean datatype in the dataset is 0

# %% [markdown]
# No,there is no boolean datatype in this dataset.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %%
ECom_Data.drop(['product_specifications','description'],axis=1)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %% [markdown]
# I am deleting the columns which are specified in the question,for that I have used axis=1.This will help in doing the column wise operation and delete the 2 columns.

# %% [markdown]
# ### Ans 2 b)

# %%
ECom_Data.drop(['product_specifications','description'],axis=1,inplace=True)

# %%
ECom_Data
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %% [markdown]
# inplace=True helps to delete the columns permanently in the original dataset.So now, the 2 columns are permanently deleted from the dataset.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (2 marks)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %%
unique_brand=ECom_Data['Brand'].nunique()
print('The total unique brand in the dataset is',unique_brand)
# Out:
# The total unique brand in the dataset is 2484

# %% [markdown]
# There are totally 2484 unique brand in the Brand column.

# %% [markdown]
# ### Ans 3 b)

# %%
avg_product_rating=ECom_Data.groupby('Brand')['product_rating'].mean()
print('The average product rating within each brand is \n',avg_product_rating)
# Out:
# The average product rating within each brand is
#  Brand
# 1OAK           1.500000
# 3A AUTOCARE    3.268293
# 3D MAT         3.000000
# 3KFACTORY      2.000000
# 4D             3.600000
#                  ...
# ZORDEN         4.000000
# ZOSIGN         3.400000
# ZRESTHA        1.000000
# ZYXEL          3.333333
#  TARKAN        5.000000
# Name: product_rating, Length: 2484, dtype: float64

# %% [markdown]
# The above output shows the average product rating within each brand.

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (3 marks

# %% [markdown]
# ### Ans 4 a)

# %%
plt.figure(figsize=(10,6))
ECom_Data['product_main_category'].value_counts().plot(kind='bar')
plt.title('Product Category type')
plt.xlabel('product_main_category')
plt.ylabel('counts')
plt.show()

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# From the plot,we can say that **maximum** orders placed under product main category is for **clothing** and **minimum** order under the same category is **Wearable smart devices**.To make it further more clear, let us see how many orders were placed under product main category.

# %%
ECom_Data.groupby('product_main_category')['product_unique ID'].count().sort_values(ascending=False)
# Out:
# product_main_category
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
#                                ...
# Pet Supplies                     20
# Home Entertainment               17
# Household Supplies                4
# Food & Nutrition                  2
# Wearable Smart Devices            1
# Name: product_unique ID, Length: 26, dtype: int64

# %% [markdown]
# From the above output, it is clear that the maximum order is for clothing which got 2943 orders and minimum is for
# wearable smart devices which got 1 order.

# %% [markdown]
# ### Ans 4 c)

# %%
top_5=ECom_Data.groupby('product_main_category')['product_unique ID'].count().sort_values(ascending=False).head()
print('The Top 5 product_main_category(s) are \n',top_5)
# Out:
# The Top 5 product_main_category(s) are
#  product_main_category
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: product_unique ID, dtype: int64

# %% [markdown]
# The above output shows the top 5 product main categories in descending order.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed. (6 marks)
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5

# %%
ECom_Data['ecom_revenue']=ECom_Data.apply(lambda row:
    row['discounted_price']*0.25 if row['discounted_price']>600 else
    (row['discounted_price']*0.15 if 350<row['discounted_price']<=600 else
    (row['discounted_price']*0.10 if 100<row['discounted_price']<=350 else
    row['discounted_price']*0.5)),axis=1)
ECom_Data
# Out:
#                       Customer_uniq_id Region Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East  2021-10-24
# 1     6286847ee2da18f587503db49511c539  East  2021-10-24
# 2     0686fec9b70e5039583a38119ca0c835   West 2021-10-24
# 3     ea2406dc597bee2abb6b867fa668501f   West 2021-10-24
# 4     5935ed077915347dc695744df68c565c  East  2021-03-09
# ...                                ...    ...        ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South 2020-01-12
# 8902  20a73e3f41490a73ceeba5f17658db8f   West 2020-01-12
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East  2020-01-12
# 8904  6b737a4deca1ed0e56c179e66036e994   West 2020-01-12
# 8905  a5235ac28d3d5487f54025f9d6b57433  North 2020-01-12
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %%
Total_revenue=ECom_Data['ecom_revenue'].sum()
print('The total revenue generated by the E-Commerce company is',Total_revenue)
# Out:
# The total revenue generated by the E-Commerce company is 2217486.85

# %% [markdown]
# Here I have used the lambda function and if else loop to compute the given conditions and stored the value in a newly created ecom_revenue column in the dataset.The total revenue is calculated using the sum() function on the ecom_revenue column.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks)
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %% [markdown]
# Creating new column 'brand_revenue' to perform subtraction and storing those values in the newly created column.

# %%
ECom_Data['brand_revenue']=ECom_Data['discounted_price']-ECom_Data['ecom_revenue']
ECom_Data
# Out:
#                       Customer_uniq_id Region Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East  2021-10-24
# 1     6286847ee2da18f587503db49511c539  East  2021-10-24
# 2     0686fec9b70e5039583a38119ca0c835   West 2021-10-24
# 3     ea2406dc597bee2abb6b867fa668501f   West 2021-10-24
# 4     5935ed077915347dc695744df68c565c  East  2021-03-09
# ...                                ...    ...        ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South 2020-01-12
# 8902  20a73e3f41490a73ceeba5f17658db8f   West 2020-01-12
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East  2020-01-12
# 8904  6b737a4deca1ed0e56c179e66036e994   West 2020-01-12
# 8905  a5235ac28d3d5487f54025f9d6b57433  North 2020-01-12
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %%
total_brand_revenue=ECom_Data.groupby('Brand')['brand_revenue'].sum().reset_index()
top_10_brands=total_brand_revenue.sort_values('brand_revenue',ascending=False).head(10)
print('Brand Revenue for each brand is')
print(total_brand_revenue)
print('The Total Brand Revenue is\n',ECom_Data['brand_revenue'].sum())
# Out:
# Brand Revenue for each brand is
#             Brand  brand_revenue
# 0            1OAK        1015.40
# 1     3A AUTOCARE       55647.90
# 2          3D MAT        5249.25
# 3       3KFACTORY         156.60
# 4              4D        5961.00
# ...           ...            ...
# 2479       ZORDEN        2099.25
# 2480       ZOSIGN        5246.25
# 2481      ZRESTHA         674.25
# 2482        ZYXEL       26544.00
# 2483       TARKAN         314.10
#
# [2484 rows x 2 columns]
# The Total Brand Revenue is
#  7522992.15

# %%
print('The top 10 Brand having maximum revenue is\n',top_10_brands)
# Out:
# The top 10 Brand having maximum revenue is
#               Brand  brand_revenue
# 93     ALLURE AUTO      498464.25
# 780           GAGA      237390.00
# 1984          SLIM      212062.60
# 512   DAILYOBJECTS      181980.00
# 578       DIVINITI      143115.00
# 2175  THELOSTPUPPY      127287.50
# 1761       REGULAR      126536.50
# 643       ENTHOPIA      123146.25
# 179           ASUS       99241.50
# 2038     SPRINGWEL       88978.50

# %% [markdown]
# The total brand revenue is **7522992.15** and the top 10 brands having maximum revenue is shown in the above output.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (3 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)

# %% [markdown]
# ### Ans 7 a)

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='retail_price',data=ECom_Data)
plt.title('Boxplot of Retail Price')
plt.xlabel('Retail Price')
plt.ylabel('Price')
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.boxplot(y='discounted_price',data=ECom_Data)
plt.title('Boxplot of Discounted Price')
plt.xlabel('Discounted Price')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# Yes,we can say that there are outliers from the above 2 boxplots.

# %% [markdown]
# ### Ans 7 c)

# %%
plt.figure(figsize=(15,6))
sns.scatterplot(x='retail_price',y='discounted_price',data=ECom_Data)
plt.title('Scatterplot of retail price and discounted price')
plt.xlabel('Retail Price')
plt.ylabel('Discounted Price')
plt.show()

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (6 marks)

# %% [markdown]
# ### Ans 8

# %%
brand_specific_information = ECom_Data.groupby('Brand').agg(
    total_orders=('Brand', 'count'),
    total_retail_price=('retail_price', 'sum'),
    total_discounted_price=('discounted_price', 'sum'),
    total_brand_revenue=('brand_revenue', 'sum')
).reset_index()
brand_specific_information
# Out:
#             Brand  total_orders  total_retail_price  total_discounted_price  \
# 0            1OAK             2                1698                    1274
# 1     3A AUTOCARE            41              107059                   74134
# 2          3D MAT             1                7250                    6999
# 3       3KFACTORY             1                 399                     174
# 4              4D             5               17500                    7948
# ...           ...           ...                 ...                     ...
# 2479       ZORDEN             1                3999                    2799
# 2480       ZOSIGN             5                6995                    6995
# 2481      ZRESTHA             1                1999                     899
# 2482        ZYXEL             9               64742                   35392
# 2483       TARKAN             1                1999                     349
#
#       total_brand_revenue
# 0                 1015.40
# ...

# %%
sns.pairplot(brand_specific_information, diag_kind="kde")
plt.suptitle('Pairplot of Brand-Specific Information',y=1.02)
plt.show()

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ### Ans 9 a)

# %%
ECom_Data['Order_Date'] = pd.to_datetime(ECom_Data['Order_Date'])
ECom_Data['Month'] = ECom_Data['Order_Date'].dt.strftime('%m-%Y')
monthly_revenue = ECom_Data.groupby(['Month', 'Region'])['ecom_revenue'].sum().reset_index()
plt.figure(figsize=(15, 6))
sns.set(style="whitegrid")
sns.lineplot(x='Month', y='ecom_revenue', hue='Region', data=monthly_revenue, marker='o')
plt.title('Monthly E-Commerce Revenue by Region')
plt.xlabel('Month')
plt.ylabel('ecom_Revenue')
plt.xticks(rotation=45)
plt.legend(title='Region')
plt.show()

# %%
ECom_Data['Order_Date'] = pd.to_datetime(ECom_Data['Order_Date'])
ECom_Data['Month'] = ECom_Data['Order_Date'].dt.strftime('%m-%Y')
monthly_revenue = ECom_Data.groupby(['Month', 'Region'])['brand_revenue'].sum().reset_index()
plt.figure(figsize=(15, 6))
sns.set(style="whitegrid")
sns.lineplot(x='Month', y='brand_revenue', hue='Region', data=monthly_revenue, marker='o')
plt.title('Monthly E-Commerce Revenue by Region')
plt.xlabel('Month')
plt.ylabel('brand_Revenue')
plt.xticks(rotation=45)
plt.legend(title='Region')
plt.show()

# %% [markdown]
# ### Ans 9 b)

# %% [markdown]
# From the above output,we can say that the best performing months for each region is:
#     East  :01-2020(january 2020)
#     North :01-2020(january 2020)
#     South :12-2020(December 2020)
#     West  :01-2020(january 2020)
# The worst performing months for each region is:
#     East  :08-2021(August 2021)
#     North :04-2020,08-2021(April 2020 and August 2021)
#     South :08-2021(August 2021)
#     West  :04-2020,08-2021(April 2020 and August 2021)

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
